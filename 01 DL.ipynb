# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (585.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 MB 2.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.7.0)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.54.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 80.3 MB/s eta 0:00:00ta 0:00:01
# Collecting wrapt<1.15,>=1.11.0
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow) (21.3)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 12.9 MB/s eta 0:00:00
# Collecting tensorboard<2.13,>=2.12
#   Downloading tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 76.5 MB/s eta 0:00:00:00:0100:01
# Collecting keras<2.13,>=2.12.0
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 73.9 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.0-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 61.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (4.21.8)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting jax>=0.3.15
#   Downloading jax-0.4.11.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 20.7 MB/s eta 0:00:00
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 12.3 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 50.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.24,>=1.22 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.23.4)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.32.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 83.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: scipy>=1.7 in /opt/conda/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow) (1.9.3)
# Collecting ml-dtypes>=0.1.0
#   Downloading ml_dtypes-0.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 32.1 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 82.5 MB/s eta 0:00:00:00:0100:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.19.1-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 27.3 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 18.5 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.3.4-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 36.6 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.28.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow) (3.0.9)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 30.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<2.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (1.26.11)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.1)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml) ... done
#   Created wheel for jax: filename=jax-0.4.11-py3-none-any.whl size=1487877 sha256=a65e1dc3e9df272db0db0f74685cb90698117d385f366b8c58dd052a89b41fef
#   Stored in directory: /home/jovyan/.cache/pip/wheels/60/ba/dd/b66da6df64fba82ddb4401361647a80bb117e33b1fbca4d0b5
# Successfully built jax
# Installing collected packages: libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, opt-einsum, ml-dtypes, markdown, keras, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, rsa, requests-oauthlib, pyasn1-modules, jax, google-auth, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.1 flatbuffers-23.5.26 gast-0.4.0 google-auth-2.19.1 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.54.2 jax-0.4.11 keras-2.12.0 libclang-16.0.0 markdown-3.4.3 ml-dtypes-0.1.0 opt-einsum-3.3.0 pyasn1-0.5.0 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.12.3 tensorboard-data-server-0.7.0 tensorflow-2.12.0 tensorflow-estimator-2.12.0 tensorflow-io-gcs-filesystem-0.32.0 termcolor-2.3.0 werkzeug-2.3.4 wrapt-1.14.1

# %%
# !pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0

# %%
import tensorflow as tf

# Download and load the MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# 2023-06-04 04:51:31.457248: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-04 04:51:31.525612: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-04 04:51:31.526432: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-04 04:51:32.693605: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
import tensorflow as tf
from tensorflow.keras import layers

# Load and preprocess the MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.reshape(-1, 28, 28, 1).astype("float32") / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype("float32") / 255.0
num_classes = 10

# CNN architecture 1
model1 = tf.keras.Sequential([
    layers.Conv2D(32, (3, 3), activation="relu", input_shape=(28, 28, 1)),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Flatten(),
    layers.Dense(128, activation="relu"),
    layers.Dense(num_classes, activation="softmax")
])

# CNN architecture 2
model2 = tf.keras.Sequential([
    layers.Conv2D(16, (3, 3), activation="relu", input_shape=(28, 28, 1)),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation="relu"),
    layers.Dense(num_classes, activation="softmax")
])

# CNN architecture 3
model3 = tf.keras.Sequential([
    layers.Conv2D(8, (3, 3), activation="relu", input_shape=(28, 28, 1)),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Flatten(),
    layers.Dense(32, activation="relu"),
    layers.Dense(num_classes, activation="softmax")
])

# Compile and train models
models = [model1, model2, model3]
histories = []

for model in models:
    model.compile(optimizer="adam",
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  metrics=["accuracy"])
    
    history = model.fit(x_train, y_train, batch_size=128, epochs=10, validation_split=0.2)
    histories.append(history)

# Evaluation
evaluations = []
for model in models:
    _, accuracy = model.evaluate(x_test, y_test)
    evaluations.append(accuracy)

# Comparison table
print("Model    Parameters    Accuracy")
print("-------  ------------  ----------")
for i, model in enumerate(models):
    parameters = model.count_params()
    accuracy = evaluations[i] * 100
    print(f"Model {i+1:2}  {parameters:12,}  {accuracy:9.2f}%")
# Out:
# Epoch 1/10
# 375/375 [==============================] - 5s 11ms/step - loss: 0.2593 - accuracy: 0.9236 - val_loss: 0.1104 - val_accuracy: 0.9680
# Epoch 2/10
# 375/375 [==============================] - 4s 10ms/step - loss: 0.0800 - accuracy: 0.9762 - val_loss: 0.0742 - val_accuracy: 0.9774
# Epoch 3/10
# 375/375 [==============================] - 4s 10ms/step - loss: 0.0535 - accuracy: 0.9843 - val_loss: 0.0667 - val_accuracy: 0.9812
# Epoch 4/10
# 375/375 [==============================] - 4s 10ms/step - loss: 0.0400 - accuracy: 0.9874 - val_loss: 0.0554 - val_accuracy: 0.9831
# Epoch 5/10
# 375/375 [==============================] - 4s 10ms/step - loss: 0.0304 - accuracy: 0.9909 - val_loss: 0.0601 - val_accuracy: 0.9826
# Epoch 6/10
# 375/375 [==============================] - 4s 11ms/step - loss: 0.0221 - accuracy: 0.9936 - val_loss: 0.0568 - val_accuracy: 0.9836
# Epoch 7/10
# 375/375 [==============================] - 4s 10ms/step - loss: 0.0178 - accuracy: 0.9945 - val_loss: 0.0568 - val_accuracy: 0.9842
# Epoch 8/10
# 375/375 [==============================] - 4s 11ms/step - loss: 0.0146 - accuracy: 0.9956 - val_loss: 0.0545 - val_accuracy: 0.9852
# Epoch 9/10
# 375/375 [==============================] - 4s 10ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 0.0603 - val_accuracy: 0.9841
# Epoch 10/10
# 375/375 [==============================] - 4s 11ms/step - loss: 0.0084 - accuracy: 0.9975 - val_loss: 0.0596 - val_accuracy: 0.9847
# Epoch 1/10
# 375/375 [==============================] - 4s 8ms/step - loss: 0.3485 - accuracy: 0.9015 - val_loss: 0.1569 - val_accuracy: 0.9568
# Epoch 2/10
# 375/375 [==============================] - 3s 8ms/step - loss: 0.1184 - accuracy: 0.9656 - val_loss: 0.1011 - val_accuracy: 0.9716
# Epoch 3/10
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0757 - accuracy: 0.9781 - val_loss: 0.0774 - val_accuracy: 0.9782
# Epoch 4/10
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0575 - accuracy: 0.9829 - val_loss: 0.0689 - val_accuracy: 0.9800
# Epoch 5/10
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0456 - accuracy: 0.9868 - val_loss: 0.0635 - val_accuracy: 0.9803
# Epoch 6/10
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0381 - accuracy: 0.9888 - val_loss: 0.0591 - val_accuracy: 0.9823
# Epoch 7/10
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0334 - accuracy: 0.9901 - val_loss: 0.0556 - val_accuracy: 0.9833
# Epoch 8/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0258 - accuracy: 0.9925 - val_loss: 0.0555 - val_accuracy: 0.9832
# Epoch 9/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.0577 - val_accuracy: 0.9821
# Epoch 10/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0170 - accuracy: 0.9954 - val_loss: 0.0604 - val_accuracy: 0.9835
# Epoch 1/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.4915 - accuracy: 0.8691 - val_loss: 0.2298 - val_accuracy: 0.9329
# Epoch 2/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1923 - accuracy: 0.9432 - val_loss: 0.1527 - val_accuracy: 0.9559
# Epoch 3/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1393 - accuracy: 0.9585 - val_loss: 0.1227 - val_accuracy: 0.9651
# Epoch 4/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1082 - accuracy: 0.9685 - val_loss: 0.1018 - val_accuracy: 0.9718
# Epoch 5/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0881 - accuracy: 0.9739 - val_loss: 0.0926 - val_accuracy: 0.9753
# Epoch 6/10
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0752 - accuracy: 0.9779 - val_loss: 0.0880 - val_accuracy: 0.9761
# Epoch 7/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0641 - accuracy: 0.9815 - val_loss: 0.0839 - val_accuracy: 0.9778
# Epoch 8/10
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0565 - accuracy: 0.9835 - val_loss: 0.0765 - val_accuracy: 0.9792
# Epoch 9/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0512 - accuracy: 0.9848 - val_loss: 0.0735 - val_accuracy: 0.9786
# Epoch 10/10
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0463 - accuracy: 0.9865 - val_loss: 0.0696 - val_accuracy: 0.9811
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0485 - accuracy: 0.9859
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0522 - accuracy: 0.9836
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0603 - accuracy: 0.9802
# Model    Parameters    Accuracy
# -------  ------------  ----------
# Model  1       693,962      98.59%
# Model  2       173,930      98.36%
# Model  3        43,706      98.02%
